# %%
print("OK")
# Out:
# OK

# %%
import os

os.chdir("../")

# %%
from langchain.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 langchain
#
# NameError: name 'langchain' is not defined
